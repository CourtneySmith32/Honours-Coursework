# %%
# %matplotlib inline
import numpy as np
import matplotlib.tri as Tri
from netCDF4 import Dataset as NetCDFFile 
import netCDF4
from netCDF4 import num2date, date2num, date2index
import datetime as dt
import pandas as pd
from StringIO import StringIO
import xarray as xr
from scipy import stats
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
import seaborn as sns
from datetime import datetime
import math
# Out:
# /Users/bgh2-ra/anaconda2/lib/python2.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /Users/bgh2-ra/anaconda2/lib/python2.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
nameCSV = 'mel_wh_month_year.csv'
df = pd.read_csv(str(nameCSV))
df
# Out:
#      January     February        March        April          May         June  \
# 0        NaN          nan          nan  1.357262492   1.68900007  1.274392873
# 1   0.514750  0.311800003  0.563500047  1.677864715  2.049000025  1.572750092
# 2        NaN  1.333482544  1.994889081  1.323571444  1.787166834  1.768750191
# 3   0.888365          nan   2.40170002  2.712875128  3.091566682          nan
# 4        NaN          nan          nan          nan          nan          nan
# 5   1.368201  1.383426308   1.26791707  2.253171508  2.444402295  2.018851442
# 6   1.011796  0.899443493  1.543548059  2.533556919  2.208184902   1.90474249
# 7   1.136234  1.105322421  1.865070743  1.663753917  1.918250063  2.476039267
# 8   0.961001  1.014672371  1.512222052  1.418839334  1.765727215  1.580857583
# 9   1.579077  1.459462202    1.7700959  2.279409891   1.68449605  2.190343747
# 10  1.389763  1.038424474  1.650821547  1.790734709  2.245318227  2.178570662
# ...

# %%
nameCSV = 'SOI_index.csv'
df1 = pd.read_csv(str(nameCSV))

# %%
df1
# Out:
#     January  February  March  April  May  June  July  August  September  \
# 0      -0.3       1.2    0.8    1.2  0.4  -0.4  -0.1     1.0        0.0
# 1       1.0      -1.0    0.5    0.3 -0.2   1.0   0.3    -0.4       -0.5
# 2      -0.7      -1.2   -1.3   -1.4 -1.3  -1.1  -1.4    -0.9       -1.0
# 3      -0.1      -0.4    0.6    0.1  0.9   0.1   1.0     1.5        1.8
# 4      -2.9      -0.9   -2.0   -1.0  0.3  -0.6  -0.6     0.4        0.1
# 5      -0.9      -0.7   -0.5   -1.2 -0.3  -0.8  -0.8    -0.9       -0.7
# 6      -0.1       0.3   -0.7   -1.3 -0.7  -0.4  -1.3    -1.2       -1.6
# 7      -0.4      -0.1    0.8   -0.7 -0.4   0.1   0.4     0.3        0.3
# 8       1.0       0.3    1.1    0.8  0.3   1.2   0.7     0.7        0.6
# 9       0.5       1.7   -0.4   -0.6 -1.3  -1.4  -0.8    -1.4       -1.4
# 10     -2.7      -2.0   -2.4   -1.4  0.3   1.0   1.2     1.2        1.0
# 11      1.8       1.0    1.3    1.4  0.2   0.3   0.5     0.4       -0.1
# ...

# %%
print df.shape
print df1.shape
# Out:
# (32, 12)
# (32, 12)

# %%
df1.corrwith(df)
# Out:
# January     -0.135026
# April             NaN
# August            NaN
# December          NaN
# February          NaN
# July              NaN
# June              NaN
# March             NaN
# May               NaN
# November          NaN
# October           NaN
# September         NaN
# dtype: float64

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = df1.astype(float)

# %%
x = df.astype(float)

# %%
x
# Out:
#      January  February     March     April       May      June      July  \
# 0        NaN       NaN       NaN  1.357262  1.689000  1.274393       NaN
# 1   0.514750  0.311800  0.563500  1.677865  2.049000  1.572750  2.039361
# 2        NaN  1.333483  1.994889  1.323571  1.787167  1.768750  2.016184
# 3   0.888365       NaN  2.401700  2.712875  3.091567       NaN  1.847028
# 4        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# June        -0.080377
# July         0.223268
# August       0.148097
# September    0.438858
# October      0.054694
# November    -0.093962
# December     0.005398
# dtype: float64

# %%
pd.concat([df1,x],axis=1).corr()
# Out:
#             January  February     March     April       May      June  \
# January    1.000000  0.574997  0.735156  0.698051 -0.122431  0.126745
# February   0.574997  1.000000  0.515843  0.501318  0.021934 -0.147968
# March      0.735156  0.515843  1.000000  0.659476  0.231520  0.265760
# April      0.698051  0.501318  0.659476  1.000000  0.346035  0.300164
# May       -0.122431  0.021934  0.231520  0.346035  1.000000  0.423574
# June       0.126745 -0.147968  0.265760  0.300164  0.423574  1.000000
# July       0.065863 -0.125180  0.284403  0.396966  0.651451  0.671560
# August    -0.198483 -0.099722  0.133969  0.291056  0.707509  0.511118
# September -0.097253 -0.089260  0.203885  0.284582  0.619503  0.538870
# October    0.160892 -0.127479  0.311349  0.309579  0.458257  0.548101
# November   0.105921  0.117007  0.352215  0.349731  0.420143  0.342704
# December   0.027645 -0.039009  0.220199  0.440436  0.489307  0.368011
# ...

# %%
df2.corrwith(x) #this by month
# Out:
# January     -0.135026
# February     0.066466
# March       -0.333814
# April       -0.456020
# May          0.434972
# June        -0.080377
# July         0.223268
# August       0.148097
# September    0.438858
# October      0.054694
# November    -0.093962
# December     0.005398
# dtype: float64

# %%
df2.corrwith(x, axis=1) #by year
# Out:
# 0     0.221462
# 1     0.124587
# 2    -0.697653
# 3     0.457693
# 4    -0.994634
# 5    -0.317346
# 6    -0.553318
# 7     0.462032
# 8     0.082280
# 9    -0.146881
# 10    0.388233
# 11   -0.807232
# 12   -0.736935
# 13   -0.004201
# 14   -0.215739
# 15    0.105770
# 16   -0.141949
# 17    0.014030
# 18   -0.727017
# 19   -0.106454
# 20   -0.568185
# 21   -0.179354
# 22    0.102772
# 23   -0.725255
# 24   -0.261681
# 25    0.521008
# 26    0.170853
# 27    0.007703
# 28    0.396863
# 29   -0.136678
# 30   -0.196293
# 31    1.000000
# dtype: float64

# %%
from matplotlib import cm as cm

fig = plt.figure()
ax1 = fig.add_subplot(111)
cmap = cm.get_cmap('jet', 30)
cax = ax1.imshow(df1.corr(), interpolation="nearest", cmap=cmap)
ax1.grid(True)
plt.title('SOI-SOI Correlation')
labels=['J','F','M','A','M','J','JUL','A','S','O','N','D']
ax1.set_xticklabels(labels,fontsize=10)
ax1.set_yticklabels(labels,fontsize=10)
# Add colorbar, make sure to specify tick locations to match desired ticklabels
fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
plt.show()

fig = plt.figure()
ax1 = fig.add_subplot(111)
cmap = cm.get_cmap('jet', 30)
cax = ax1.imshow(x.corr(), interpolation="nearest", cmap=cmap)
ax1.grid(True)
plt.title('wh-wh Correlation')
labels=['J','F','M','A','M','J','JUL','A','S','O','N','D']
ax1.set_xticklabels(labels,fontsize=10)
ax1.set_yticklabels(labels,fontsize=10)
# Add colorbar, make sure to specify tick locations to match desired ticklabels
fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
plt.show()

# %%
sns.heatmap(x.corrwith(df2))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-398d51feda88> in <module>()
# ----> 1 sns.heatmap(x.corrwith(df2))
#
# /Users/bgh2-ra/anaconda2/lib/python2.7/site-packages/seaborn/matrix.pyc in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# /Users/bgh2-ra/anaconda2/lib/python2.7/site-packages/seaborn/matrix.pyc in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
fig=plt.plot(df.wh)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-029cc9788a1d> in <module>()
# ----> 1 fig=plt.plot(df.wh)
#
# /Users/bgh2-ra/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'wh'

# %%
nameCSV = 'soi_wh.csv'
df55 = pd.read_csv(str(nameCSV))

# %%
df55
# Out:
#      soi        wh
# 0   -0.9  1.368201
# 1   -0.7  1.383426
# 2   -0.5  1.267917
# 3   -1.2  2.253172
# 4   -0.3  2.444402
# 5   -0.8  2.018851
# 6   -0.8  1.839939
# 7   -0.9  1.603995
# 8   -0.7  1.841643
# 9   -1.1  1.569902
# 10  -0.1  1.322313
# 11   0.2  1.277822
# 12  -0.1  1.011796
# 13   0.3  0.899443
# 14  -0.7  1.543548
# 15  -1.3  2.533557
# 16  -0.7  2.208185
# 17  -0.4  1.904742
# 18  -1.3  2.318837
# 19  -1.2  2.430231
# 20  -1.6  1.568320
# 21  -1.1  1.459072
# 22  -0.6  1.287811
# 23  -1.2  1.153464
# 24  -0.4  1.136234
# 25  -0.1  1.105322
# 26   0.8  1.865071
# 27  -0.7  1.663754
# 28  -0.4  1.918250
# 29   0.1  2.476039
# ..   ...       ...
# 282  0.4  2.093469
# 283  0.7  2.145879
# 284  1.2  1.684191
# 285 -0.3  1.666647
# 286 -0.1  1.076790
# 287  0.3  1.126544
# 288  0.2  0.646187
# 289 -0.1  1.025580
# 290  0.9  0.934062
# 291 -0.2  2.388148
# 292  0.3  2.105903
# 293 -0.4  2.389832
# 294  0.8  2.223470
# 295  0.5  1.876795
# 296  0.6  2.192649
# ...

# %%
df555 = df55.astype(float)

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
daaata = df555[soi,wh]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-79644d7b235e> in <module>()
# ----> 1 daaata = df555[soi,wh]
#
# NameError: name 'soi' is not defined

# %%
df555['soi'].corr(df555['wh'])
# Out:
# -0.09856955851624423

# %%
df555.corr(method='pearson')
# Out:
#          soi       wh
# soi  1.00000 -0.09857
# wh  -0.09857  1.00000

# %%
df555.corr()
# Out:
#          soi       wh
# soi  1.00000 -0.09857
# wh  -0.09857  1.00000

# %%
df555.corr(method='pearson')
# Out:
#          soi       wh
# soi  1.00000 -0.09857
# wh  -0.09857  1.00000

# %%
dd = df555[['soi','wh']]
correlation=dd.corr(method='pearson')

# %%
correlation
# Out:
#          soi       wh
# soi  1.00000 -0.09857
# wh  -0.09857  1.00000

# %%
dffloat = np.float64(df555['wh'])

# %%
# Out:
# array([1.36820127, 1.38342631, 1.26791707, 2.25317151, 2.4444023 ,
#        2.01885144, 1.83993945, 1.60399522, 1.84164308, 1.56990209,
#        1.32231318, 1.2778216 , 1.01179563, 0.89944349, 1.54354806,
#        2.53355692, 2.2081849 , 1.90474249, 2.31883747, 2.43023055,
#        1.56832043, 1.45907248, 1.28781072, 1.15346385, 1.1362336 ,
#        1.10532242, 1.86507074, 1.66375392, 1.91825006, 2.47603927,
#        1.80999632, 2.92637365, 1.91865283, 1.75676005, 1.23958454,
#        1.03937855, 0.9610007 , 1.01467237, 1.51222205, 1.41883933,
#        1.76572722, 1.58085758, 1.28333562, 1.79899695, 1.56144813,
#        2.62110093, 1.04681235, 1.25006557, 1.5790773 , 1.4594622 ,
#        1.7700959 , 2.27940989, 1.68449605, 2.19034375, 2.55020154,
#        2.1394158 , 1.57776285, 1.48048548, 1.34849477, 0.98639604,
#        1.38976282, 1.03842447, 1.65082155, 1.79073471, 2.24531823,
#        2.17857066, 2.55438204, 1.98802573, 2.1265181 , 1.40331056,
# ...
